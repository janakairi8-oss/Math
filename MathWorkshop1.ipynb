# %% [markdown]
# <a href="https://colab.research.google.com/github/janakairi8-oss/Math/blob/main/MathWorkshop1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Name : Anil Airi**
# * *University Id : 2614037*

# %%
lenght = 5
width = 2
area = lenght*width
print(area)
# Out:
# 10

# %%
base = 4
height = 9
area = base*height/2
print("Area is "+ str(area))
# Out:
# Area is 18.0

# %%
hrs = input("Enter Hours:")
h = float(hrs)
rate = input("Enter the rate per hour:")
r = float(rate)
if h <= 40:
 pay = h*r
else:
  pay = (40*r) + (h-40)*(r*1.5)
print(pay)
# Out:
# Enter Hours:45
# Enter the rate per hour:100
# 4750.0

# %%
def greeting (name):
 print("welcome "+ name)
greeting("Anil")
# Out:
# welcome Anil

# %%
def area_traingle(b, h):
 return b*h/2
area = area_traingle(4, 8)
print("area of traingle is: " + str(area))
# Out:
# area of traingle is: 16.0

# %%
def order_numbers(number1, number2):
 if number2 > number1:
  return (number1,number2)
 else:
   return (number2,number1)
print(order_numbers(4,5))
# Out:
# (4, 5)

# %%
def is_Even(number):
  if (number%2 == 0):
   return True
  return False
print(is_Even(8))
# Out:
# True

# %%
def number_group(number):
  if number > 0:
    return "Positive"
  elif number == 0:
   return "Zero"
  else:
   return "Negative"
print(number_group(10))
print(number_group(0))
print(number_group(-5))
# Out:
# Positive
# Zero
# Negative

# %%
x = 0
while x<5:
  print("Not there yet, x= " + str(x))
  x = x+1
print("x= "+str(x))
# Out:
# Not there yet, x= 0
# Not there yet, x= 1
# Not there yet, x= 2
# Not there yet, x= 3
# Not there yet, x= 4
# x= 5

# %%
def count_down(start_number):
  current=3
  while (current > 0):
    print(current)
    current -= 1
print("Zero!")
count_down(3)
# Out:
# Zero!
# 3
# 2
# 1

# %%
while x != 0 and x%2 == 0:
  x = x/2

# %%
for x in range(5):
  print(x)

# %%
def square(n):
  return n*n
def sum_squares(x):
  sum = 0
  for n in range(10):
    sum += square(n)
  return sum
print(sum_squares(10))

# %%
values = [10, 20, 30, 40, 50]
Sum = 0
length = 0
for value in values:
  Sum = Sum+value
  length = length+1
print("Total sum= "+str(Sum)+" and the Average="+str(Sum/length))

# %%
for left in range(7):
  for right in range(left, 7):
    print("["+str(left)+"|"+str(right)+"]", end=" ")
  print()

# %%
hrs = input("Enter Hours:")
h = float(hrs)
rate = input("Enter the rate per hour:")
r = float(rate)
if h<=40:
  pay = h*r
else:
  overtime=h-40
  pay=(40*r)+(overtime*r*1.5)
print("Pay:",pay)

# %%
def fib(n):
  a=0
  b=1
  i=0
  while i<n:
    print(a)
    c=a+b
    a=b
    b=c
    i=i+1
fib(10)

# %%
def mypow(x, n):
    result = 1
    i = 0
    while i < n:
        result = result * x
        i = i + 1
    return result

print(mypow(5, 2))

# %%
def sumDigit(x):
  sum=0
  i=0
  while x!=0:
    s=x%10
    sum+=s
    x=x//10
  return sum
print(sumDigit(10))

# %%
def square_sum(x):
  x=x+1
  sum=0
  for x in range(x):
    sum+=x
  return sum
print(square_sum(3))
